# %%
import sys
import os
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from scripts.load_dicom import load_dicom

# %%
# %load_ext autoreload
# %autoreload 2

# %%
path = os.path.abspath(os.path.join(os.getcwd(), "..", "data", "1685", "10_AP_Ax2.50mm"))

print(f"Loading DICOM files from {path}")
slices = load_dicom(path)

print(f"Number of slices: {len(slices)}")
# Out:
# Loading DICOM files from c:\Users\josep\Documents\Master\11763-Medical-Image-Processing-Final-Project\data\1685\10_AP_Ax2.50mm
# Number of slices: 86

# %%
print (f"First slice: {slices[0]}")
# Out:
# First slice: Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 174
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.2.840.113704.1.111.3956.1410855854.4865
# (0002,0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002,0013) Implementation Version Name         SH: 'dcm4che-1.4-JP'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008,0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'HELIX']
# (0008,0012) Instance Creation Date              DA: ''
# (0008,0013) Instance Creation Time              TM: '102414'
# (0008,0016) SOP Class UID                       UI: CT Image Storage
# (0008,0017) Acquisition UID                     UI: 1801040320200103051513090319.1685.1.0.0
# (0008,0018) SOP Instance UID                    UI: 1.2.840.113704.1.111.3956.1410855854.4865
# (0008,0020) Study Date                          DA: ''
# (0008,0022) Acquisition Date                    DA: ''
# (0008,0023) Content Date                        DA: ''
# (0008,0030) Study Time                          TM: '100639'
# (0008,0032) Acquisition Time                    TM: '102023'
# (0008,0033) Content Time                        TM: '102023.757999'
# (0008,0050) Accession Number                    SH: '4073615366796275'
# (0008,0060) Modality                            CS: 'CT'
# (0008,0070) Manufacturer                        LO: 'Philips'
# (0008,0090) Referring Physician's Name          PN: ''
# (0008,1030) Study Description                   LO: 'RadCTTACEomics_1685 AP'
# (0008,1032)  Procedure Code Sequence  1 item(s) ----
#    (0008,0100) Code Value                          SH: 'TCHIGTRI'
#    (0008,0102) Coding Scheme Designator            SH: 'L'
#    (0008,0104) Code Meaning                        LO: 'TC higado, estudio trifasico'
#    ---------
# (0008,103E) Series Description                  LO: '10_AP_Ax2.50mm'
# (0008,1090) Manufacturer's Model Name           LO: 'Brilliance 16'
# (0010,0010) Patient's Name                      PN: 'RadCTTACEomics_1685'
# (0010,0020) Patient ID                          LO: '1685'
# (0010,0030) Patient's Birth Date                DA: ''
# (0010,0040) Patient's Sex                       CS: 'M'
# (0010,1010) Patient's Age                       AS: '066Y'
# (0010,1030) Patient's Weight                    DS: None
# (0012,0062) Patient Identity Removed            CS: 'YES'
# (0012,0063) De-identification Method            LO: 'CTP Default:  based on DICOM PS3.15 AnnexE. Details in 0012,0064'
# (0012,0064)  De-identification Method Code Sequence  5 item(s) ----
#    (0008,0100) Code Value                          SH: '113100'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008,0100) Code Value                          SH: '113105'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113107'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113108'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113109'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
# (0018,0022) Scan Options                        CS: 'HELIX'
# (0018,0050) Slice Thickness                     DS: '5.00'
# (0018,0060) KVP                                 DS: '120'
# (0018,0088) Spacing Between Slices              DS: '2.5'
# (0018,0090) Data Collection Diameter            DS: '500'
# (0018,1020) Software Versions                   LO: '2.3.0'
# (0018,1040) Contrast/Bolus Route                LO: ''
# (0018,1041) Contrast/Bolus Volume               DS: None
# (0018,1046) Contrast Flow Rate                  DS: None
# (0018,1049) Contrast/Bolus Ingredient Concentra DS: None
# (0018,1100) Reconstruction Diameter             DS: '393'
# (0018,1120) Gantry/Detector Tilt                DS: '0'
# (0018,1130) Table Height                        DS: '169'
# (0018,1140) Rotation Direction                  CS: 'CW'
# (0018,1151) X-Ray Tube Current                  IS: '438'
# (0018,1152) Exposure                            IS: '350'
# (0018,1160) Filter Type                         SH: 'B'
# (0018,1210) Convolution Kernel                  SH: 'B'
# (0018,5100) Patient Position                    CS: 'FFS'
# (0018,9321)  CT Exposure Sequence  1 item(s) ----
#    (0018,9324) Estimated Dose Saving               FD: 0.0
#    (0018,9328) Exposure Time in ms                 FD: 0.7990867579908676
#    (0018,9330) X-Ray Tube Current in mA            FD: 438.0
#    (0018,9332) Exposure in mAs                     FD: 350.0
#    (0018,9345) CTDIvol                             FD: 24.7
#    ---------
# (0018,9323) Exposure Modulation Type            CS: ''
# (0018,9345) CTDIvol                             FD: 24.7
# (0020,000D) Study Instance UID                  UI: 1801040320200103051513090319.1685.1
# (0020,000E) Series Instance UID                 UI: 1801040320200103051513090319.1685.1.0
# (0020,0010) Study ID                            SH: '1685-AP'
# (0020,0011) Series Number                       IS: '0'
# (0020,0012) Acquisition Number                  IS: None
# (0020,0013) Instance Number                     IS: '1'
# (0020,0032) Image Position (Patient)            DS: [-215.5, -110.5, 976]
# (0020,0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020,0052) Frame of Reference UID              UI: 1.2.840.113654.2.70.1.48350248958791986651232638618120738778
# (0020,0060) Laterality                          CS: ''
# (0020,1040) Position Reference Indicator        LO: ''
# (0020,1041) Slice Location                      DS: '-976.00'
# (0028,0002) Samples per Pixel                   US: 1
# (0028,0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028,0008) Number of Frames                    IS: '1'
# (0028,0010) Rows                                US: 512
# (0028,0011) Columns                             US: 512
# (0028,0030) Pixel Spacing                       DS: [0.767578, 0.767578]
# (0028,0100) Bits Allocated                      US: 16
# (0028,0101) Bits Stored                         US: 11
# (0028,0102) High Bit                            US: 10
# (0028,0103) Pixel Representation                US: 1
# (0028,0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028,1050) Window Center                       DS: [00050, 00050]
# (0028,1051) Window Width                        DS: [00350, 00350]
# (0028,1052) Rescale Intercept                   DS: '0'
# (0028,1053) Rescale Slope                       DS: '1'
# (7FE0,0010) Pixel Data                          OW: Array of 524288 elements

# %%
for i in range(len(slices)):
    print(f"Slice {i}: {slices[i].InstanceNumber}")
# Out:
# Slice 0: 1
# Slice 1: 2
# Slice 2: 3
# Slice 3: 4
# Slice 4: 5
# Slice 5: 6
# Slice 6: 7
# Slice 7: 8
# Slice 8: 9
# Slice 9: 10
# Slice 10: 11
# Slice 11: 12
# Slice 12: 13
# Slice 13: 14
# Slice 14: 15
# Slice 15: 16
# Slice 16: 17
# Slice 17: 18
# Slice 18: 19
# Slice 19: 20
# Slice 20: 21
# Slice 21: 22
# Slice 22: 23
# Slice 23: 24
# Slice 24: 25
# Slice 25: 26
# Slice 26: 27
# Slice 27: 28
# Slice 28: 29
# Slice 29: 30
# Slice 30: 31
# Slice 31: 32
# Slice 32: 33
# Slice 33: 34
# Slice 34: 35
# Slice 35: 36
# Slice 36: 37
# Slice 37: 38
# Slice 38: 39
# Slice 39: 40
# Slice 40: 41
# Slice 41: 42
# Slice 42: 43
# Slice 43: 44
# Slice 44: 45
# Slice 45: 46
# Slice 46: 47
# Slice 47: 48
# Slice 48: 49
# Slice 49: 50
# Slice 50: 51
# Slice 51: 52
# Slice 52: 53
# Slice 53: 54
# Slice 54: 55
# Slice 55: 56
# Slice 56: 57
# Slice 57: 58
# Slice 58: 59
# Slice 59: 60
# Slice 60: 61
# Slice 61: 62
# Slice 62: 63
# Slice 63: 64
# Slice 64: 65
# Slice 65: 66
# Slice 66: 67
# Slice 67: 68
# Slice 68: 69
# Slice 69: 70
# Slice 70: 71
# Slice 71: 72
# Slice 72: 73
# Slice 73: 74
# Slice 74: 75
# Slice 75: 76
# Slice 76: 77
# Slice 77: 78
# Slice 78: 79
# Slice 79: 80
# Slice 80: 81
# Slice 81: 82
# Slice 82: 83
# Slice 83: 84
# Slice 84: 85
# Slice 85: 86

# %%
index = 30
plt.imshow(slices[index].pixel_array, cmap='gray')
plt.title(f"Instance Number: {slices[index].InstanceNumber}")
plt.axis('off')
plt.show()
